# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as Data
from torch.utils.data import DataLoader, TensorDataset, Dataset
import pandas as pd
import numpy as np
from scipy.stats import t, shapiro, kstest
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import itertools

# %%
#data preparation
def prepare_data():
    #loading data
    abundance = pd.read_csv('~/icr/simko/data/simko2_data/passport_prots.csv', index_col=0)
    abundance.index = abundance.index.astype(str)
    #removing cell lines with over 4000 nans
    nans_per_cl = abundance.isna().sum(axis=0)
    abundance_cl_filtered = abundance.loc[:, nans_per_cl<4000]
    #getting rid of protein with over 80% NaN (from the dataset filtered by CLs)
    prot_nan_count = abundance_cl_filtered.isna().sum(axis=1)
    prot_nan_percent = (prot_nan_count/abundance_cl_filtered.shape[1])*100
    abundance_filtered = abundance_cl_filtered[prot_nan_percent<80]

    #imputing witht the lower quartile average for each protein
    #set the protein names as the index - ignores it while we find the lower quartile
    def average_lower_quartile(x):
        sorted_abundances = x.dropna().sort_values()
        lower_qt_values = sorted_abundances.iloc[:int(len(sorted_abundances) * 0.25)]
        return lower_qt_values.mean()


    lower_qt_averages = abundance_filtered.apply(average_lower_quartile, axis=1)
    abundance_filtered_no_nan = abundance_filtered.apply(lambda x: x.fillna(lower_qt_averages[x.name]), axis=1)

    #transposing
    abundance_imputed = abundance_filtered_no_nan.T
    #scaling the imputed data
    scaler = StandardScaler()
    scaled_data = pd.DataFrame(scaler.fit_transform(abundance_imputed), index=abundance_imputed.index, columns=abundance_imputed.columns)
    #scaled_data = scaled_data.T
    return scaled_data

scaled_data = prepare_data()

# %%
#getting pbrm1 values so we can make the continuous - put the values between 0 and 1
raw_pbrm1 = scaled_data["PBRM1"].values
raw_min, raw_max = raw_pbrm1.min(), raw_pbrm1.max()
#condition = 
c = (raw_pbrm1 - raw_min) / (raw_max - raw_min)

# %%
# getting rid of pbrm1 from data set to use in training
X = scaled_data.drop(columns=["PBRM1"]).values.astype(np.float32)

# %%
n_proteins = X.shape[1]     # after dropping PBRM1

# %%
#creating custom data set --> makes it easier to proccess it later on (data augmentation)
class ProteomeDataset(Dataset):
    def __init__(self, X, c):
        self.X = torch.from_numpy(X).float()
        self.c = torch.from_numpy(c).float().unsqueeze(-1)
    def __len__(self):
        return len(self.X)
    def __getitem__(self, i):
        return self.X[i], self.c[i]

full_ds = ProteomeDataset(X, c)
loader  = DataLoader(full_ds, batch_size=32, shuffle=True, drop_last=True)

# %%
# 1) Factory for a 3-layer CVAE
def make_cvae_3layer(n_proteins, latent_dim, activation, dropout):
    act_fn = {
        'relu': nn.ReLU(),
        'lrelu': nn.LeakyReLU(0.1),
        'elu': nn.ELU(),
        'gelu': nn.GELU()
    }[activation]
    
    # Encoder: [in → 3 hidden layers → μ/logvar]
    enc = nn.Sequential(
        nn.Linear(n_proteins + 1, 800),
        nn.BatchNorm1d(800), act_fn, nn.Dropout(dropout),
        nn.Linear(800, 400),
        nn.BatchNorm1d(400), act_fn, nn.Dropout(dropout),
        nn.Linear(400, 200),
        nn.BatchNorm1d(200), act_fn, nn.Dropout(dropout),
    )
    fc_mu     = nn.Linear(200, latent_dim)
    fc_logvar = nn.Linear(200, latent_dim)

    # Decoder: [z+c → 3 hidden layers → out]
    dec = nn.Sequential(
        nn.Linear(latent_dim + 1, 200),
        nn.BatchNorm1d(200), act_fn, nn.Dropout(dropout),
        nn.Linear(200, 400),
        nn.BatchNorm1d(400), act_fn, nn.Dropout(dropout),
        nn.Linear(400, 800),
        nn.BatchNorm1d(800), act_fn, nn.Dropout(dropout),
        nn.Linear(800, n_proteins),
        nn.ReLU(),
    )

    class CVAE(nn.Module):
        def __init__(self):
            super().__init__()
            self.enc, self.fc_mu, self.fc_logvar, self.dec = enc, fc_mu, fc_logvar, dec

        def reparameterize(self, mu, logvar):
            std = (0.5 * logvar).exp()
            eps = torch.randn_like(std)
            return mu + eps * std

        def forward(self, x, c):
            h = self.enc(torch.cat([x, c], 1))
            mu, logvar = self.fc_mu(h), self.fc_logvar(h)
            z = self.reparameterize(mu, logvar)
            x_rec = self.dec(torch.cat([z, c], 1))
            return x_rec, mu, logvar

    return CVAE()

# %%
# 3) Training function with per-element MSE & KL logging
# ------------------------------------------------------
def train_one(model, loader, epochs=30, warmup=20, eps=0.02):
    opt = torch.optim.Adam(model.parameters(), lr=1e-3)
    n_proteins = next(iter(loader))[0].shape[1]

    for epoch in range(1, epochs+1):
        model.train()
        β = min(1.0, epoch / warmup)
        sum_recon, sum_kl = 0.0, 0.0
        for x, c in loader:
            x, c = x, c
            # jitter c
            c_noisy = torch.clamp(c + torch.randn_like(c)*eps, 0, 1)
            x_rec, mu, logvar = model(x, c_noisy)
            recon = F.mse_loss(x_rec, x, reduction='sum')
            kl    = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
            loss  = recon + β * kl

            opt.zero_grad(); loss.backward(); opt.step()
            sum_recon += recon.item()
            sum_kl    += kl.item()

        # per-element metrics
        total_elems = len(loader.dataset) * n_proteins
        mse_elem = sum_recon / total_elems
        rmse_elem = np.sqrt(mse_elem)
        avg_kl = sum_kl / len(loader.dataset)

        # print diagnostic
        print(f"[{epoch:02d}/{epochs}] β={β:.2f}  "
              f"MSE_elem={mse_elem:.4f}  RMSE={rmse_elem:.4f}  KL_per_samp={avg_kl:.2f}")

# %%
# 4) Evaluation function returning per-element MSE
# -------------------------------------------------
def eval_mse(model, loader):
    model.eval()
    sum_se = 0.0
    with torch.no_grad():
        for x, c in loader:
            x, c = x, c
            x_rec, _, _ = model(x, c)
            sum_se += F.mse_loss(x_rec, x, reduction='sum').item()
    total_elems = len(loader.dataset) * n_proteins
    return sum_se / total_elems

# %%
# 3) Hyperparameter grid
activations = ['relu','lrelu','elu','gelu']
dropouts    = [0.0, 0.2, 0.5]
latents     = [10, 20, 50, 100]

results = []

for act in activations:
    for dr in dropouts:
        for zdim in latents:
            print(f"\n>>> Testing act={act}, dropout={dr}, latent={zdim}")
            model = make_cvae_3layer(n_proteins, zdim, act, dr)
            train_one(model, loader, epochs=40, warmup=10, eps=0.02)
            mse = eval_mse(model, loader)
            print(f"→ Final per-element MSE: {mse:.4f}")
            results.append((act, dr, zdim, mse))
# Out:
# >>> Testing act=relu, dropout=0.0, latent=10
# [01/40] β=0.10  MSE_elem=0.9966  RMSE=0.9983  KL_per_samp=7.26
# [02/40] β=0.20  MSE_elem=0.9776  RMSE=0.9887  KL_per_samp=16.84
# [03/40] β=0.30  MSE_elem=0.9712  RMSE=0.9855  KL_per_samp=19.56
# [04/40] β=0.40  MSE_elem=0.9684  RMSE=0.9841  KL_per_samp=19.34
# [05/40] β=0.50  MSE_elem=0.9663  RMSE=0.9830  KL_per_samp=19.31
# [06/40] β=0.60  MSE_elem=0.9623  RMSE=0.9810  KL_per_samp=18.92
# [07/40] β=0.70  MSE_elem=0.9602  RMSE=0.9799  KL_per_samp=19.08
# [08/40] β=0.80  MSE_elem=0.9585  RMSE=0.9790  KL_per_samp=18.43
# [09/40] β=0.90  MSE_elem=0.9568  RMSE=0.9782  KL_per_samp=17.93
# [10/40] β=1.00  MSE_elem=0.9556  RMSE=0.9775  KL_per_samp=17.53
# [11/40] β=1.00  MSE_elem=0.9535  RMSE=0.9765  KL_per_samp=17.45
# [12/40] β=1.00  MSE_elem=0.9504  RMSE=0.9749  KL_per_samp=17.79
# [13/40] β=1.00  MSE_elem=0.9491  RMSE=0.9742  KL_per_samp=18.10
# [14/40] β=1.00  MSE_elem=0.9473  RMSE=0.9733  KL_per_samp=18.40
# [15/40] β=1.00  MSE_elem=0.9460  RMSE=0.9726  KL_per_samp=18.83
# [16/40] β=1.00  MSE_elem=0.9446  RMSE=0.9719  KL_per_samp=19.24
# [17/40] β=1.00  MSE_elem=0.9423  RMSE=0.9707  KL_per_samp=19.15
# [18/40] β=1.00  MSE_elem=0.9404  RMSE=0.9697  KL_per_samp=19.30
# [19/40] β=1.00  MSE_elem=0.9376  RMSE=0.9683  KL_per_samp=19.76
# [20/40] β=1.00  MSE_elem=0.9357  RMSE=0.9673  KL_per_samp=20.08
# [21/40] β=1.00  MSE_elem=0.9346  RMSE=0.9668  KL_per_samp=20.64
# [22/40] β=1.00  MSE_elem=0.9330  RMSE=0.9659  KL_per_samp=20.68
# [23/40] β=1.00  MSE_elem=0.9299  RMSE=0.9643  KL_per_samp=20.60
# [24/40] β=1.00  MSE_elem=0.9289  RMSE=0.9638  KL_per_samp=20.76
# [25/40] β=1.00  MSE_elem=0.9269  RMSE=0.9627  KL_per_samp=21.30
# [26/40] β=1.00  MSE_elem=0.9256  RMSE=0.9621  KL_per_samp=21.67
# [27/40] β=1.00  MSE_elem=0.9247  RMSE=0.9616  KL_per_samp=21.82
# [28/40] β=1.00  MSE_elem=0.9232  RMSE=0.9608  KL_per_samp=21.40
# [29/40] β=1.00  MSE_elem=0.9217  RMSE=0.9600  KL_per_samp=22.15
# [30/40] β=1.00  MSE_elem=0.9193  RMSE=0.9588  KL_per_samp=22.47
# [31/40] β=1.00  MSE_elem=0.9178  RMSE=0.9580  KL_per_samp=22.48
# [32/40] β=1.00  MSE_elem=0.9157  RMSE=0.9569  KL_per_samp=22.58
# [33/40] β=1.00  MSE_elem=0.9152  RMSE=0.9567  KL_per_samp=22.38
# [34/40] β=1.00  MSE_elem=0.9136  RMSE=0.9558  KL_per_samp=23.33
# [35/40] β=1.00  MSE_elem=0.9118  RMSE=0.9549  KL_per_samp=23.51
# [36/40] β=1.00  MSE_elem=0.9102  RMSE=0.9540  KL_per_samp=23.59
# [37/40] β=1.00  MSE_elem=0.9089  RMSE=0.9534  KL_per_samp=23.92
# [38/40] β=1.00  MSE_elem=0.9070  RMSE=0.9523  KL_per_samp=24.17
# [39/40] β=1.00  MSE_elem=0.9059  RMSE=0.9518  KL_per_samp=24.29
# [40/40] β=1.00  MSE_elem=0.9028  RMSE=0.9502  KL_per_samp=24.43
# → Final per-element MSE: 0.8914
#
# >>> Testing act=relu, dropout=0.0, latent=20
# [01/40] β=0.10  MSE_elem=0.9997  RMSE=0.9998  KL_per_samp=8.86
# [02/40] β=0.20  MSE_elem=0.9804  RMSE=0.9901  KL_per_samp=20.83
# [03/40] β=0.30  MSE_elem=0.9733  RMSE=0.9866  KL_per_samp=25.56
# [04/40] β=0.40  MSE_elem=0.9683  RMSE=0.9840  KL_per_samp=24.27
# [05/40] β=0.50  MSE_elem=0.9655  RMSE=0.9826  KL_per_samp=23.56
# [06/40] β=0.60  MSE_elem=0.9623  RMSE=0.9809  KL_per_samp=23.37
# [07/40] β=0.70  MSE_elem=0.9598  RMSE=0.9797  KL_per_samp=23.16
# [08/40] β=0.80  MSE_elem=0.9572  RMSE=0.9784  KL_per_samp=22.91
# [09/40] β=0.90  MSE_elem=0.9555  RMSE=0.9775  KL_per_samp=22.56
# [10/40] β=1.00  MSE_elem=0.9526  RMSE=0.9760  KL_per_samp=21.79
# [11/40] β=1.00  MSE_elem=0.9502  RMSE=0.9748  KL_per_samp=21.99
# [12/40] β=1.00  MSE_elem=0.9477  RMSE=0.9735  KL_per_samp=23.38
# [13/40] β=1.00  MSE_elem=0.9452  RMSE=0.9722  KL_per_samp=22.79
# [14/40] β=1.00  MSE_elem=0.9437  RMSE=0.9714  KL_per_samp=23.19
# [15/40] β=1.00  MSE_elem=0.9423  RMSE=0.9707  KL_per_samp=23.77
# [16/40] β=1.00  MSE_elem=0.9401  RMSE=0.9696  KL_per_samp=24.03
# [17/40] β=1.00  MSE_elem=0.9383  RMSE=0.9686  KL_per_samp=24.41
# [18/40] β=1.00  MSE_elem=0.9354  RMSE=0.9672  KL_per_samp=25.10
# [19/40] β=1.00  MSE_elem=0.9341  RMSE=0.9665  KL_per_samp=24.98
# [20/40] β=1.00  MSE_elem=0.9321  RMSE=0.9655  KL_per_samp=25.43
# [21/40] β=1.00  MSE_elem=0.9306  RMSE=0.9647  KL_per_samp=25.77
# [22/40] β=1.00  MSE_elem=0.9297  RMSE=0.9642  KL_per_samp=25.84
# [23/40] β=1.00  MSE_elem=0.9285  RMSE=0.9636  KL_per_samp=25.88
# [24/40] β=1.00  MSE_elem=0.9267  RMSE=0.9626  KL_per_samp=26.66
# [25/40] β=1.00  MSE_elem=0.9245  RMSE=0.9615  KL_per_samp=26.93
# [26/40] β=1.00  MSE_elem=0.9236  RMSE=0.9611  KL_per_samp=26.54
# [27/40] β=1.00  MSE_elem=0.9219  RMSE=0.9602  KL_per_samp=27.05
# [28/40] β=1.00  MSE_elem=0.9200  RMSE=0.9592  KL_per_samp=27.01
# [29/40] β=1.00  MSE_elem=0.9200  RMSE=0.9592  KL_per_samp=27.32
# [30/40] β=1.00  MSE_elem=0.9182  RMSE=0.9582  KL_per_samp=26.83
# [31/40] β=1.00  MSE_elem=0.9164  RMSE=0.9573  KL_per_samp=27.99
# [32/40] β=1.00  MSE_elem=0.9147  RMSE=0.9564  KL_per_samp=27.12
# [33/40] β=1.00  MSE_elem=0.9130  RMSE=0.9555  KL_per_samp=28.20
# [34/40] β=1.00  MSE_elem=0.9120  RMSE=0.9550  KL_per_samp=28.00
# [35/40] β=1.00  MSE_elem=0.9113  RMSE=0.9546  KL_per_samp=28.47
# [36/40] β=1.00  MSE_elem=0.9085  RMSE=0.9531  KL_per_samp=28.51
# [37/40] β=1.00  MSE_elem=0.9071  RMSE=0.9524  KL_per_samp=29.44
# [38/40] β=1.00  MSE_elem=0.9075  RMSE=0.9526  KL_per_samp=29.03
# [39/40] β=1.00  MSE_elem=0.9057  RMSE=0.9517  KL_per_samp=29.30
# [40/40] β=1.00  MSE_elem=0.9029  RMSE=0.9502  KL_per_samp=29.11
# → Final per-element MSE: 0.8925
#
# >>> Testing act=relu, dropout=0.0, latent=50
# [01/40] β=0.10  MSE_elem=1.0009  RMSE=1.0004  KL_per_samp=13.59
# [02/40] β=0.20  MSE_elem=0.9824  RMSE=0.9911  KL_per_samp=27.12
# [03/40] β=0.30  MSE_elem=0.9775  RMSE=0.9887  KL_per_samp=30.98
# [04/40] β=0.40  MSE_elem=0.9756  RMSE=0.9877  KL_per_samp=28.19
# [05/40] β=0.50  MSE_elem=0.9738  RMSE=0.9868  KL_per_samp=26.14
# [06/40] β=0.60  MSE_elem=0.9722  RMSE=0.9860  KL_per_samp=25.31
# [07/40] β=0.70  MSE_elem=0.9713  RMSE=0.9855  KL_per_samp=22.95
# [08/40] β=0.80  MSE_elem=0.9694  RMSE=0.9846  KL_per_samp=23.78
# [09/40] β=0.90  MSE_elem=0.9685  RMSE=0.9841  KL_per_samp=22.01
# [10/40] β=1.00  MSE_elem=0.9679  RMSE=0.9838  KL_per_samp=22.08
# [11/40] β=1.00  MSE_elem=0.9661  RMSE=0.9829  KL_per_samp=21.90
# [12/40] β=1.00  MSE_elem=0.9648  RMSE=0.9822  KL_per_samp=21.95
# [13/40] β=1.00  MSE_elem=0.9638  RMSE=0.9817  KL_per_samp=22.14
# [14/40] β=1.00  MSE_elem=0.9623  RMSE=0.9809  KL_per_samp=22.32
# [15/40] β=1.00  MSE_elem=0.9621  RMSE=0.9809  KL_per_samp=23.11
# [16/40] β=1.00  MSE_elem=0.9614  RMSE=0.9805  KL_per_samp=22.32
# [17/40] β=1.00  MSE_elem=0.9591  RMSE=0.9793  KL_per_samp=23.16
# [18/40] β=1.00  MSE_elem=0.9584  RMSE=0.9790  KL_per_samp=23.69
# [19/40] β=1.00  MSE_elem=0.9580  RMSE=0.9788  KL_per_samp=23.83
# [20/40] β=1.00  MSE_elem=0.9565  RMSE=0.9780  KL_per_samp=23.89
# [21/40] β=1.00  MSE_elem=0.9552  RMSE=0.9773  KL_per_samp=23.61
# [22/40] β=1.00  MSE_elem=0.9537  RMSE=0.9766  KL_per_samp=23.68
# [23/40] β=1.00  MSE_elem=0.9530  RMSE=0.9762  KL_per_samp=23.84
# [24/40] β=1.00  MSE_elem=0.9516  RMSE=0.9755  KL_per_samp=23.17
# [25/40] β=1.00  MSE_elem=0.9511  RMSE=0.9752  KL_per_samp=24.39
# [26/40] β=1.00  MSE_elem=0.9501  RMSE=0.9747  KL_per_samp=24.08
# [27/40] β=1.00  MSE_elem=0.9488  RMSE=0.9741  KL_per_samp=23.95
# [28/40] β=1.00  MSE_elem=0.9484  RMSE=0.9739  KL_per_samp=23.97
# [29/40] β=1.00  MSE_elem=0.9476  RMSE=0.9734  KL_per_samp=24.22
# [30/40] β=1.00  MSE_elem=0.9469  RMSE=0.9731  KL_per_samp=24.54
# [31/40] β=1.00  MSE_elem=0.9456  RMSE=0.9724  KL_per_samp=23.81
# [32/40] β=1.00  MSE_elem=0.9436  RMSE=0.9714  KL_per_samp=24.61
# [33/40] β=1.00  MSE_elem=0.9428  RMSE=0.9710  KL_per_samp=24.74
# [34/40] β=1.00  MSE_elem=0.9417  RMSE=0.9704  KL_per_samp=24.75
# [35/40] β=1.00  MSE_elem=0.9413  RMSE=0.9702  KL_per_samp=24.47
# [36/40] β=1.00  MSE_elem=0.9404  RMSE=0.9698  KL_per_samp=25.02
# [37/40] β=1.00  MSE_elem=0.9399  RMSE=0.9695  KL_per_samp=25.11
# [38/40] β=1.00  MSE_elem=0.9385  RMSE=0.9687  KL_per_samp=25.16
# [39/40] β=1.00  MSE_elem=0.9375  RMSE=0.9682  KL_per_samp=24.83
# [40/40] β=1.00  MSE_elem=0.9365  RMSE=0.9677  KL_per_samp=25.02
# → Final per-element MSE: 0.9301
#
# >>> Testing act=relu, dropout=0.0, latent=100
# [01/40] β=0.10  MSE_elem=0.9993  RMSE=0.9996  KL_per_samp=22.85
# [02/40] β=0.20  MSE_elem=0.9795  RMSE=0.9897  KL_per_samp=38.70
# [03/40] β=0.30  MSE_elem=0.9740  RMSE=0.9869  KL_per_samp=35.54
# [04/40] β=0.40  MSE_elem=0.9704  RMSE=0.9851  KL_per_samp=32.27
# [05/40] β=0.50  MSE_elem=0.9679  RMSE=0.9838  KL_per_samp=30.94
# [06/40] β=0.60  MSE_elem=0.9657  RMSE=0.9827  KL_per_samp=30.12
# [07/40] β=0.70  MSE_elem=0.9629  RMSE=0.9813  KL_per_samp=28.00
# [08/40] β=0.80  MSE_elem=0.9607  RMSE=0.9802  KL_per_samp=27.15
# [09/40] β=0.90  MSE_elem=0.9596  RMSE=0.9796  KL_per_samp=27.06
# [10/40] β=1.00  MSE_elem=0.9579  RMSE=0.9787  KL_per_samp=26.44
# [11/40] β=1.00  MSE_elem=0.9559  RMSE=0.9777  KL_per_samp=26.27
# [12/40] β=1.00  MSE_elem=0.9548  RMSE=0.9771  KL_per_samp=26.99
# [13/40] β=1.00  MSE_elem=0.9534  RMSE=0.9764  KL_per_samp=26.09
# [14/40] β=1.00  MSE_elem=0.9510  RMSE=0.9752  KL_per_samp=27.45
# [15/40] β=1.00  MSE_elem=0.9511  RMSE=0.9752  KL_per_samp=27.14
# [16/40] β=1.00  MSE_elem=0.9484  RMSE=0.9739  KL_per_samp=27.76
# [17/40] β=1.00  MSE_elem=0.9467  RMSE=0.9730  KL_per_samp=28.27
# [18/40] β=1.00  MSE_elem=0.9455  RMSE=0.9723  KL_per_samp=28.03
# [19/40] β=1.00  MSE_elem=0.9441  RMSE=0.9716  KL_per_samp=29.01
# [20/40] β=1.00  MSE_elem=0.9436  RMSE=0.9714  KL_per_samp=29.12
# [21/40] β=1.00  MSE_elem=0.9417  RMSE=0.9704  KL_per_samp=29.33
# [22/40] β=1.00  MSE_elem=0.9404  RMSE=0.9697  KL_per_samp=29.88
# [23/40] β=1.00  MSE_elem=0.9398  RMSE=0.9695  KL_per_samp=30.18
# [24/40] β=1.00  MSE_elem=0.9378  RMSE=0.9684  KL_per_samp=29.84
# [25/40] β=1.00  MSE_elem=0.9358  RMSE=0.9674  KL_per_samp=29.70
# [26/40] β=1.00  MSE_elem=0.9352  RMSE=0.9671  KL_per_samp=30.00
# [27/40] β=1.00  MSE_elem=0.9343  RMSE=0.9666  KL_per_samp=30.08
# [28/40] β=1.00  MSE_elem=0.9321  RMSE=0.9655  KL_per_samp=31.42
# [29/40] β=1.00  MSE_elem=0.9314  RMSE=0.9651  KL_per_samp=30.90
# [30/40] β=1.00  MSE_elem=0.9306  RMSE=0.9647  KL_per_samp=31.42
# [31/40] β=1.00  MSE_elem=0.9290  RMSE=0.9639  KL_per_samp=31.62
# [32/40] β=1.00  MSE_elem=0.9292  RMSE=0.9640  KL_per_samp=31.10
# [33/40] β=1.00  MSE_elem=0.9284  RMSE=0.9635  KL_per_samp=31.35
# [34/40] β=1.00  MSE_elem=0.9257  RMSE=0.9621  KL_per_samp=31.04
# [35/40] β=1.00  MSE_elem=0.9257  RMSE=0.9621  KL_per_samp=32.20
# [36/40] β=1.00  MSE_elem=0.9233  RMSE=0.9609  KL_per_samp=32.14
# [37/40] β=1.00  MSE_elem=0.9236  RMSE=0.9610  KL_per_samp=32.02
# [38/40] β=1.00  MSE_elem=0.9218  RMSE=0.9601  KL_per_samp=31.20
# [39/40] β=1.00  MSE_elem=0.9206  RMSE=0.9595  KL_per_samp=31.65
# [40/40] β=1.00  MSE_elem=0.9191  RMSE=0.9587  KL_per_samp=32.64
# → Final per-element MSE: 0.9112
#
# >>> Testing act=relu, dropout=0.2, latent=10
# [01/40] β=0.10  MSE_elem=1.0055  RMSE=1.0028  KL_per_samp=4.74
# [02/40] β=0.20  MSE_elem=0.9898  RMSE=0.9949  KL_per_samp=10.75
# [03/40] β=0.30  MSE_elem=0.9812  RMSE=0.9906  KL_per_samp=14.40
# [04/40] β=0.40  MSE_elem=0.9734  RMSE=0.9866  KL_per_samp=15.30
# [05/40] β=0.50  MSE_elem=0.9687  RMSE=0.9842  KL_per_samp=16.23
# [06/40] β=0.60  MSE_elem=0.9636  RMSE=0.9816  KL_per_samp=16.15
# [07/40] β=0.70  MSE_elem=0.9603  RMSE=0.9799  KL_per_samp=16.45
# [08/40] β=0.80  MSE_elem=0.9556  RMSE=0.9775  KL_per_samp=15.54
# [09/40] β=0.90  MSE_elem=0.9524  RMSE=0.9759  KL_per_samp=15.60
# [10/40] β=1.00  MSE_elem=0.9498  RMSE=0.9746  KL_per_samp=16.77
# [11/40] β=1.00  MSE_elem=0.9469  RMSE=0.9731  KL_per_samp=16.01
# [12/40] β=1.00  MSE_elem=0.9442  RMSE=0.9717  KL_per_samp=16.74
# [13/40] β=1.00  MSE_elem=0.9402  RMSE=0.9697  KL_per_samp=16.68
# [14/40] β=1.00  MSE_elem=0.9379  RMSE=0.9684  KL_per_samp=16.95
# [15/40] β=1.00  MSE_elem=0.9364  RMSE=0.9677  KL_per_samp=17.23
# [16/40] β=1.00  MSE_elem=0.9326  RMSE=0.9657  KL_per_samp=17.52
# [17/40] β=1.00  MSE_elem=0.9311  RMSE=0.9649  KL_per_samp=17.76
# [18/40] β=1.00  MSE_elem=0.9293  RMSE=0.9640  KL_per_samp=18.21
# [19/40] β=1.00  MSE_elem=0.9277  RMSE=0.9632  KL_per_samp=18.68
# [20/40] β=1.00  MSE_elem=0.9257  RMSE=0.9621  KL_per_samp=19.06
# [21/40] β=1.00  MSE_elem=0.9245  RMSE=0.9615  KL_per_samp=19.60
# [22/40] β=1.00  MSE_elem=0.9223  RMSE=0.9604  KL_per_samp=19.59
# [23/40] β=1.00  MSE_elem=0.9201  RMSE=0.9592  KL_per_samp=18.95
# [24/40] β=1.00  MSE_elem=0.9178  RMSE=0.9580  KL_per_samp=19.46
# [25/40] β=1.00  MSE_elem=0.9172  RMSE=0.9577  KL_per_samp=19.48
# [26/40] β=1.00  MSE_elem=0.9144  RMSE=0.9563  KL_per_samp=19.69
# [27/40] β=1.00  MSE_elem=0.9143  RMSE=0.9562  KL_per_samp=20.49
# [28/40] β=1.00  MSE_elem=0.9122  RMSE=0.9551  KL_per_samp=19.95
# [29/40] β=1.00  MSE_elem=0.9106  RMSE=0.9543  KL_per_samp=20.34
# [30/40] β=1.00  MSE_elem=0.9079  RMSE=0.9528  KL_per_samp=20.50
# [31/40] β=1.00  MSE_elem=0.9062  RMSE=0.9519  KL_per_samp=20.36
# [32/40] β=1.00  MSE_elem=0.9055  RMSE=0.9516  KL_per_samp=20.75
# [33/40] β=1.00  MSE_elem=0.9057  RMSE=0.9517  KL_per_samp=21.29
# [34/40] β=1.00  MSE_elem=0.9019  RMSE=0.9497  KL_per_samp=21.45
# [35/40] β=1.00  MSE_elem=0.9019  RMSE=0.9497  KL_per_samp=21.36
# [36/40] β=1.00  MSE_elem=0.9001  RMSE=0.9487  KL_per_samp=21.82
# [37/40] β=1.00  MSE_elem=0.9003  RMSE=0.9488  KL_per_samp=21.97
# [38/40] β=1.00  MSE_elem=0.8974  RMSE=0.9473  KL_per_samp=22.27
# [39/40] β=1.00  MSE_elem=0.8972  RMSE=0.9472  KL_per_samp=22.42
# [40/40] β=1.00  MSE_elem=0.8973  RMSE=0.9473  KL_per_samp=22.43
# → Final per-element MSE: 0.8796
#
# >>> Testing act=relu, dropout=0.2, latent=20
# [01/40] β=0.10  MSE_elem=1.0074  RMSE=1.0037  KL_per_samp=4.96
# [02/40] β=0.20  MSE_elem=0.9957  RMSE=0.9979  KL_per_samp=9.33
# [03/40] β=0.30  MSE_elem=0.9898  RMSE=0.9949  KL_per_samp=14.63
# [04/40] β=0.40  MSE_elem=0.9837  RMSE=0.9918  KL_per_samp=17.05
# [05/40] β=0.50  MSE_elem=0.9759  RMSE=0.9879  KL_per_samp=18.03
# [06/40] β=0.60  MSE_elem=0.9680  RMSE=0.9839  KL_per_samp=17.83
# [07/40] β=0.70  MSE_elem=0.9615  RMSE=0.9806  KL_per_samp=18.99
# [08/40] β=0.80  MSE_elem=0.9564  RMSE=0.9779  KL_per_samp=19.24
# [09/40] β=0.90  MSE_elem=0.9518  RMSE=0.9756  KL_per_samp=19.67
# [10/40] β=1.00  MSE_elem=0.9468  RMSE=0.9730  KL_per_samp=19.77
# [11/40] β=1.00  MSE_elem=0.9430  RMSE=0.9711  KL_per_samp=19.68
# [12/40] β=1.00  MSE_elem=0.9390  RMSE=0.9690  KL_per_samp=20.99
# [13/40] β=1.00  MSE_elem=0.9354  RMSE=0.9672  KL_per_samp=23.07
# [14/40] β=1.00  MSE_elem=0.9326  RMSE=0.9657  KL_per_samp=23.34
# [15/40] β=1.00  MSE_elem=0.9282  RMSE=0.9634  KL_per_samp=23.76
# [16/40] β=1.00  MSE_elem=0.9249  RMSE=0.9617  KL_per_samp=23.43
# [17/40] β=1.00  MSE_elem=0.9233  RMSE=0.9609  KL_per_samp=24.28
# [18/40] β=1.00  MSE_elem=0.9226  RMSE=0.9605  KL_per_samp=24.48
# [19/40] β=1.00  MSE_elem=0.9188  RMSE=0.9585  KL_per_samp=25.33
# [20/40] β=1.00  MSE_elem=0.9165  RMSE=0.9573  KL_per_samp=25.59
# [21/40] β=1.00  MSE_elem=0.9149  RMSE=0.9565  KL_per_samp=26.44
# [22/40] β=1.00  MSE_elem=0.9148  RMSE=0.9565  KL_per_samp=26.37
# [23/40] β=1.00  MSE_elem=0.9115  RMSE=0.9547  KL_per_samp=26.68
# [24/40] β=1.00  MSE_elem=0.9098  RMSE=0.9538  KL_per_samp=27.07
# [25/40] β=1.00  MSE_elem=0.9090  RMSE=0.9534  KL_per_samp=26.96
# [26/40] β=1.00  MSE_elem=0.9067  RMSE=0.9522  KL_per_samp=26.32
# [27/40] β=1.00  MSE_elem=0.9042  RMSE=0.9509  KL_per_samp=26.18
# [28/40] β=1.00  MSE_elem=0.9031  RMSE=0.9503  KL_per_samp=26.97
# [29/40] β=1.00  MSE_elem=0.9026  RMSE=0.9501  KL_per_samp=27.57
# [30/40] β=1.00  MSE_elem=0.8998  RMSE=0.9486  KL_per_samp=27.22
# [31/40] β=1.00  MSE_elem=0.8998  RMSE=0.9486  KL_per_samp=27.62
# [32/40] β=1.00  MSE_elem=0.9011  RMSE=0.9493  KL_per_samp=27.38
# [33/40] β=1.00  MSE_elem=0.8986  RMSE=0.9480  KL_per_samp=26.86
# [34/40] β=1.00  MSE_elem=0.8980  RMSE=0.9476  KL_per_samp=27.65
# [35/40] β=1.00  MSE_elem=0.8951  RMSE=0.9461  KL_per_samp=28.27
# [36/40] β=1.00  MSE_elem=0.8943  RMSE=0.9457  KL_per_samp=28.80
# [37/40] β=1.00  MSE_elem=0.8935  RMSE=0.9452  KL_per_samp=28.80
# [38/40] β=1.00  MSE_elem=0.8923  RMSE=0.9446  KL_per_samp=28.54
# [39/40] β=1.00  MSE_elem=0.8904  RMSE=0.9436  KL_per_samp=28.21
# [40/40] β=1.00  MSE_elem=0.8867  RMSE=0.9416  KL_per_samp=28.19
# → Final per-element MSE: 0.8723
#
# >>> Testing act=relu, dropout=0.2, latent=50
# [01/40] β=0.10  MSE_elem=1.0077  RMSE=1.0038  KL_per_samp=10.20
# [02/40] β=0.20  MSE_elem=0.9964  RMSE=0.9982  KL_per_samp=14.09
# [03/40] β=0.30  MSE_elem=0.9914  RMSE=0.9957  KL_per_samp=18.60
# [04/40] β=0.40  MSE_elem=0.9839  RMSE=0.9919  KL_per_samp=19.69
# [05/40] β=0.50  MSE_elem=0.9770  RMSE=0.9884  KL_per_samp=20.36
# [06/40] β=0.60  MSE_elem=0.9720  RMSE=0.9859  KL_per_samp=18.06
# [07/40] β=0.70  MSE_elem=0.9674  RMSE=0.9836  KL_per_samp=19.51
# [08/40] β=0.80  MSE_elem=0.9641  RMSE=0.9819  KL_per_samp=17.34
# [09/40] β=0.90  MSE_elem=0.9616  RMSE=0.9806  KL_per_samp=19.54
# [10/40] β=1.00  MSE_elem=0.9585  RMSE=0.9790  KL_per_samp=18.74
# [11/40] β=1.00  MSE_elem=0.9559  RMSE=0.9777  KL_per_samp=18.02
# [12/40] β=1.00  MSE_elem=0.9537  RMSE=0.9766  KL_per_samp=19.23
# [13/40] β=1.00  MSE_elem=0.9520  RMSE=0.9757  KL_per_samp=19.77
# [14/40] β=1.00  MSE_elem=0.9483  RMSE=0.9738  KL_per_samp=20.46
# [15/40] β=1.00  MSE_elem=0.9456  RMSE=0.9724  KL_per_samp=22.20
# [16/40] β=1.00  MSE_elem=0.9436  RMSE=0.9714  KL_per_samp=22.52
# [17/40] β=1.00  MSE_elem=0.9413  RMSE=0.9702  KL_per_samp=23.24
# [18/40] β=1.00  MSE_elem=0.9385  RMSE=0.9688  KL_per_samp=24.01
# [19/40] β=1.00  MSE_elem=0.9363  RMSE=0.9676  KL_per_samp=25.02
# [20/40] β=1.00  MSE_elem=0.9353  RMSE=0.9671  KL_per_samp=25.89
# [21/40] β=1.00  MSE_elem=0.9329  RMSE=0.9659  KL_per_samp=24.93
# [22/40] β=1.00  MSE_elem=0.9282  RMSE=0.9634  KL_per_samp=27.09
# [23/40] β=1.00  MSE_elem=0.9275  RMSE=0.9631  KL_per_samp=27.59
# [24/40] β=1.00  MSE_elem=0.9249  RMSE=0.9617  KL_per_samp=26.45
# [25/40] β=1.00  MSE_elem=0.9236  RMSE=0.9610  KL_per_samp=26.88
# [26/40] β=1.00  MSE_elem=0.9231  RMSE=0.9608  KL_per_samp=28.56
# [27/40] β=1.00  MSE_elem=0.9211  RMSE=0.9597  KL_per_samp=27.92
# [28/40] β=1.00  MSE_elem=0.9188  RMSE=0.9585  KL_per_samp=27.97
# [29/40] β=1.00  MSE_elem=0.9169  RMSE=0.9575  KL_per_samp=28.98
# [30/40] β=1.00  MSE_elem=0.9163  RMSE=0.9572  KL_per_samp=27.62
# [31/40] β=1.00  MSE_elem=0.9152  RMSE=0.9566  KL_per_samp=28.12
# [32/40] β=1.00  MSE_elem=0.9138  RMSE=0.9559  KL_per_samp=28.04
# [33/40] β=1.00  MSE_elem=0.9127  RMSE=0.9554  KL_per_samp=28.03
# [34/40] β=1.00  MSE_elem=0.9096  RMSE=0.9538  KL_per_samp=28.34
# [35/40] β=1.00  MSE_elem=0.9104  RMSE=0.9541  KL_per_samp=27.94
# [36/40] β=1.00  MSE_elem=0.9103  RMSE=0.9541  KL_per_samp=28.15
# [37/40] β=1.00  MSE_elem=0.9083  RMSE=0.9530  KL_per_samp=29.63
# [38/40] β=1.00  MSE_elem=0.9077  RMSE=0.9527  KL_per_samp=28.65
# [39/40] β=1.00  MSE_elem=0.9090  RMSE=0.9534  KL_per_samp=28.95
# [40/40] β=1.00  MSE_elem=0.9069  RMSE=0.9523  KL_per_samp=29.52
# → Final per-element MSE: 0.8927
#
# >>> Testing act=relu, dropout=0.2, latent=100
# [01/40] β=0.10  MSE_elem=1.0069  RMSE=1.0034  KL_per_samp=22.17
# [02/40] β=0.20  MSE_elem=0.9926  RMSE=0.9963  KL_per_samp=25.55
# [03/40] β=0.30  MSE_elem=0.9836  RMSE=0.9918  KL_per_samp=29.40
# [04/40] β=0.40  MSE_elem=0.9748  RMSE=0.9873  KL_per_samp=27.09
# [05/40] β=0.50  MSE_elem=0.9682  RMSE=0.9840  KL_per_samp=26.39
# [06/40] β=0.60  MSE_elem=0.9637  RMSE=0.9817  KL_per_samp=26.07
# [07/40] β=0.70  MSE_elem=0.9606  RMSE=0.9801  KL_per_samp=25.17
# [08/40] β=0.80  MSE_elem=0.9565  RMSE=0.9780  KL_per_samp=25.19
# [09/40] β=0.90  MSE_elem=0.9544  RMSE=0.9769  KL_per_samp=25.04
# [10/40] β=1.00  MSE_elem=0.9522  RMSE=0.9758  KL_per_samp=24.06
# [11/40] β=1.00  MSE_elem=0.9485  RMSE=0.9739  KL_per_samp=23.04
# [12/40] β=1.00  MSE_elem=0.9458  RMSE=0.9725  KL_per_samp=26.72
# [13/40] β=1.00  MSE_elem=0.9430  RMSE=0.9711  KL_per_samp=25.17
# [14/40] β=1.00  MSE_elem=0.9415  RMSE=0.9703  KL_per_samp=26.46
# [15/40] β=1.00  MSE_elem=0.9384  RMSE=0.9687  KL_per_samp=28.45
# [16/40] β=1.00  MSE_elem=0.9370  RMSE=0.9680  KL_per_samp=26.96
# [17/40] β=1.00  MSE_elem=0.9359  RMSE=0.9674  KL_per_samp=30.91
# [18/40] β=1.00  MSE_elem=0.9341  RMSE=0.9665  KL_per_samp=32.51
# [19/40] β=1.00  MSE_elem=0.9320  RMSE=0.9654  KL_per_samp=30.13
# [20/40] β=1.00  MSE_elem=0.9299  RMSE=0.9643  KL_per_samp=29.89
# [21/40] β=1.00  MSE_elem=0.9287  RMSE=0.9637  KL_per_samp=29.08
# [22/40] β=1.00  MSE_elem=0.9265  RMSE=0.9625  KL_per_samp=31.24
# [23/40] β=1.00  MSE_elem=0.9244  RMSE=0.9615  KL_per_samp=31.74
# [24/40] β=1.00  MSE_elem=0.9250  RMSE=0.9618  KL_per_samp=32.42
# [25/40] β=1.00  MSE_elem=0.9221  RMSE=0.9603  KL_per_samp=32.53
# [26/40] β=1.00  MSE_elem=0.9197  RMSE=0.9590  KL_per_samp=31.85
# [27/40] β=1.00  MSE_elem=0.9189  RMSE=0.9586  KL_per_samp=32.01
# [28/40] β=1.00  MSE_elem=0.9176  RMSE=0.9579  KL_per_samp=32.47
# [29/40] β=1.00  MSE_elem=0.9163  RMSE=0.9572  KL_per_samp=32.50
# [30/40] β=1.00  MSE_elem=0.9164  RMSE=0.9573  KL_per_samp=33.12
# [31/40] β=1.00  MSE_elem=0.9146  RMSE=0.9564  KL_per_samp=33.94
# [32/40] β=1.00  MSE_elem=0.9125  RMSE=0.9552  KL_per_samp=34.14
# [33/40] β=1.00  MSE_elem=0.9116  RMSE=0.9548  KL_per_samp=33.42
# [34/40] β=1.00  MSE_elem=0.9112  RMSE=0.9545  KL_per_samp=33.19
# [35/40] β=1.00  MSE_elem=0.9084  RMSE=0.9531  KL_per_samp=33.28
# [36/40] β=1.00  MSE_elem=0.9112  RMSE=0.9546  KL_per_samp=32.90
# [37/40] β=1.00  MSE_elem=0.9089  RMSE=0.9534  KL_per_samp=33.96
# [38/40] β=1.00  MSE_elem=0.9067  RMSE=0.9522  KL_per_samp=33.13
# [39/40] β=1.00  MSE_elem=0.9075  RMSE=0.9526  KL_per_samp=33.79
# [40/40] β=1.00  MSE_elem=0.9065  RMSE=0.9521  KL_per_samp=34.48
# → Final per-element MSE: 0.8921
#
# >>> Testing act=relu, dropout=0.5, latent=10
# [01/40] β=0.10  MSE_elem=1.0152  RMSE=1.0076  KL_per_samp=3.04
# [02/40] β=0.20  MSE_elem=1.0001  RMSE=1.0001  KL_per_samp=3.03
# [03/40] β=0.30  MSE_elem=1.0001  RMSE=1.0000  KL_per_samp=2.85
# [04/40] β=0.40  MSE_elem=1.0001  RMSE=1.0000  KL_per_samp=2.58
# [05/40] β=0.50  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=2.17
# [06/40] β=0.60  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.96
# [07/40] β=0.70  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.73
# [08/40] β=0.80  MSE_elem=1.0001  RMSE=1.0000  KL_per_samp=1.61
# [09/40] β=0.90  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.47
# [10/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.30
# [11/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.21
# [12/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.11
# [13/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.00
# [14/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.91
# [15/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.83
# [16/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.76
# [17/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.68
# [18/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.63
# [19/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.59
# [20/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.54
# [21/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.48
# [22/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.44
# [23/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.42
# [24/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.39
# [25/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.36
# [26/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.34
# [27/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.31
# [28/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.30
# [29/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.27
# [30/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.25
# [31/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.24
# [32/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.23
# [33/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.22
# [34/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.20
# [35/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.19
# [36/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.18
# [37/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.17
# [38/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.16
# [39/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.15
# [40/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.14
# → Final per-element MSE: 1.0000
#
# >>> Testing act=relu, dropout=0.5, latent=20
# [01/40] β=0.10  MSE_elem=1.0162  RMSE=1.0081  KL_per_samp=5.52
# [02/40] β=0.20  MSE_elem=1.0001  RMSE=1.0000  KL_per_samp=5.68
# [03/40] β=0.30  MSE_elem=1.0001  RMSE=1.0000  KL_per_samp=5.01
# [04/40] β=0.40  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=4.29
# [05/40] β=0.50  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=3.83
# [06/40] β=0.60  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=3.48
# [07/40] β=0.70  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=3.01
# [08/40] β=0.80  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=2.60
# [09/40] β=0.90  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=2.28
# [10/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.94
# [11/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.62
# [12/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.45
# [13/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.23
# [14/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=1.07
# [15/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.97
# [16/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.84
# [17/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.74
# [18/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.65
# [19/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.58
# [20/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.56
# [21/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.50
# [22/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.47
# [23/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.42
# [24/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.40
# [25/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.37
# [26/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.34
# [27/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.32
# [28/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.30
# [29/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.27
# [30/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.25
# [31/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.24
# [32/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.22
# [33/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.21
# [34/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.20
# [35/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.19
# [36/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.19
# [37/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.16
# [38/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.16
# [39/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.15
# [40/40] β=1.00  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=0.14
# → Final per-element MSE: 1.0000
#
# >>> Testing act=relu, dropout=0.5, latent=50
# [01/40] β=0.10  MSE_elem=1.0152  RMSE=1.0076  KL_per_samp=12.97
# [02/40] β=0.20  MSE_elem=1.0001  RMSE=1.0001  KL_per_samp=12.49
# [03/40] β=0.30  MSE_elem=1.0001  RMSE=1.0000  KL_per_samp=10.95
# [04/40] β=0.40  MSE_elem=1.0001  RMSE=1.0000  KL_per_samp=9.29
# [05/40] β=0.50  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=8.22
# [06/40] β=0.60  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=7.19
# [07/40] β=0.70  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=5.98
# [08/40] β=0.80  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=4.76
# [09/40] β=0.90  MSE_elem=1.0000  RMSE=1.0000  KL_per_samp=3.72
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 13
#      11 print(f"\n>>> Testing act={act}, dropout={dr}, latent={zdim}")
#      12 model = make_cvae_3layer(n_proteins, zdim, act, dr)
# ---> 13 train_one(model, loader, epochs=40, warmup=10, eps=0.02)
#      14 mse = eval_mse(model, loader)
#      15 print(f"→ Final per-element MSE: {mse:.4f}")
#
# Cell In[44], line 20, in train_one(model, loader, epochs, warmup, eps)
#      17 kl    = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
#      18 loss  = recon + β * kl
# ---> 20 opt.zero_grad(); loss.backward(); opt.step()
#      21 sum_recon += recon.item()
#      22 sum_kl    += kl.item()
#
# File /opt/anaconda3/envs/icr/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File /opt/anaconda3/envs/icr/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
best = min(results, key=lambda x: x[-1])
print("\n=== Best config ===")
print(f"Activation:   {best[0]}")
print(f"Dropout:      {best[1]}")
print(f"Latent dim:   {best[2]}")
print(f"MSE per elt.: {best[3]:.4f}")
# Out:
# >>> Best hyperparams: (1, 400, 50, 'lrelu', 0.0) with per-element MSE = 0.45979664098698225
